# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/EY_batch7_18Sep/blob/main/19_Sep_002_Intro_To_ML_and_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Supervised v/s Unsupervised
# Supervised-> LABELS are identified
# Unsupervised -> we don't know what column could be a label!!!

# Supervised-> Classification and Regression
# Unsupervised -> Clustering, Recommendation engine, matrix factorization, reducing features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/cleaned_data.csv')

# %%
data.head()
# Out:
#                    location  total_sqft  bath   price  BHK
# 0  Electronic City Phase II      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4
# 2               Uttarahalli      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3
# 4                  Kothanur      1200.0   2.0   51.00    2

# %%
data.columns
# Out:
# Index(['location', 'total_sqft', 'bath', 'price', 'BHK'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11562 entries, 0 to 11561
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    11562 non-null  object
#  1   total_sqft  11562 non-null  float64
#  2   bath        11562 non-null  float64
#  3   price       11562 non-null  float64
#  4   BHK         11562 non-null  int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 451.8+ KB

# %%
# Pandas - 2 ways of slicing and dicing
# either by index of columns or by names of columns
# index -> iloc
# name -> loc

# %%
# exclude the last column and include all others
# loc and iloc => [row selection, column selection]
# :   means that all the values in that selection should be considered
#.  2:4 means 2,3
#.  3:5 means 3,4
#.  1:-1 means ignore the first and the last column

data = data.iloc[ : , :-1 ]
data.head()
# Out:
#                    location  total_sqft  bath   price
# 0  Electronic City Phase II      1056.0   2.0   39.07
# 1          Chikka Tirupathi      2600.0   5.0  120.00
# 2               Uttarahalli      1440.0   2.0   62.00
# 3        Lingadheeranahalli      1521.0   3.0   95.00
# 4                  Kothanur      1200.0   2.0   51.00

# %%
data.columns # i want to select maybe only a few columns to experiment
# just for sampling lets go with all MEAN VALUES!
# Out:
# Index(['location', 'total_sqft', 'bath', 'price'], dtype='object')

# %%
considered_cols = ['location', 'total_sqft', 'bath', 'price']

considered_data = data.loc[ :, considered_cols]
considered_data.head()
# Out:
#                    location  total_sqft  bath   price
# 0  Electronic City Phase II      1056.0   2.0   39.07
# 1          Chikka Tirupathi      2600.0   5.0  120.00
# 2               Uttarahalli      1440.0   2.0   62.00
# 3        Lingadheeranahalli      1521.0   3.0   95.00
# 4                  Kothanur      1200.0   2.0   51.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['total_sqft'].plot(kind='hist', bins=20, title='total_sqft')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['bath'].plot(kind='hist', bins=20, title='bath')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('location').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='total_sqft', y='bath', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='bath', y='price', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['total_sqft'].plot(kind='line', figsize=(8, 4), title='total_sqft')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['bath'].plot(kind='line', figsize=(8, 4), title='bath')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['price'].plot(kind='line', figsize=(8, 4), title='price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['location'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='total_sqft', y='location', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['location'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='bath', y='location', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['location'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='price', y='location', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# HEATMAP -> correlations
input_cols = [ 'total_sqft', 'bath', 'price']
data2 = data.loc[:, input_cols]
data2.corr()
# Out:
#             total_sqft      bath     price
# total_sqft    1.000000  0.544537  0.708198
# bath          0.544537  1.000000  0.590372
# price         0.708198  0.590372  1.000000

# %%
sns.heatmap(data2.corr(), cmap='coolwarm')
# Out:
# <Axes: >

# %%
# if you want to use a UNIQUE-VALUED column in dataset without including in ML
# you can make it an INDEX

# %%
# how many unique values exist in each column

considered_data.nunique()

# since ID has distinct values per row, we can convert it into INDEX!
# Out:
# location       241
# total_sqft    1799
# bath             8
# price         1842
# dtype: int64

# %%
considered_data.set_index('location', inplace=True)
considered_data.tail(10)
# Out:
#                        total_sqft  bath   price
# location
# Hulimavu                    500.0   1.0  220.00
# Billekahalli               1805.0   3.0  134.00
# Bannerghatta Road          1527.0   3.0  142.00
# Yeshwanthpur               1675.0   3.0   92.13
# Rachenahalli               1050.0   2.0   52.71
# Bellandur                  1262.0   2.0   47.00
# Green Glen Layout          1715.0   3.0  112.00
# Whitefield                 3453.0   4.0  231.00
# other                      3600.0   5.0  400.00
# Raja Rajeshwari Nagar      1141.0   2.0   60.00

# %%
Y = considered_data['price']
X = considered_data.iloc[:, 1:]

# %%
X.head()
# Out:
#                           bath   price
# location
# Electronic City Phase II   2.0   39.07
# Chikka Tirupathi           5.0  120.00
# Uttarahalli                2.0   62.00
# Lingadheeranahalli         3.0   95.00
# Kothanur                   2.0   51.00

# %%
Y.head()
# Out:
# location
# Electronic City Phase II     39.07
# Chikka Tirupathi            120.00
# Uttarahalli                  62.00
# Lingadheeranahalli           95.00
# Kothanur                     51.00
# Name: price, dtype: float64

# %%
# we always calculate assumptions on training data and then apply them to testing data

# assumption -> stats -> Mean, Standard Dev, Min, Max

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.2)

# %%
xtrain.head()
# Out:
#                           bath  price
# location
# Uttarahalli                2.0   42.6
# Karuna Nagar               3.0  170.0
# Kodihalli                  2.0  150.0
# Raja Rajeshwari Nagar      2.0   70.0
# Electronics City Phase 1   2.0   65.0

# %%
ytrain.head()
# Out:
# location
# Uttarahalli                  42.6
# Karuna Nagar                170.0
# Kodihalli                   150.0
# Raja Rajeshwari Nagar        70.0
# Electronics City Phase 1     65.0
# Name: price, dtype: float64

# %%
xtest.head()
# Out:
#                         bath   price
# location
# other                    3.0   70.00
# Kengeri Satellite Town   2.0   78.00
# Sarjapur  Road           2.0   40.72
# other                    2.0   57.15
# Rajaji Nagar             3.0  415.00

# %%
ytest.head()
# Out:
# location
# other                      70.00
# Kengeri Satellite Town     78.00
# Sarjapur  Road             40.72
# other                      57.15
# Rajaji Nagar              415.00
# Name: price, dtype: float64

# %%
# statistical assumptions-> lets extract mean, std from xtrain and apply it to testing data

xtrain.describe().T
# Out:
#         count       mean        std  min   25%   50%    75%    max
# bath   9249.0   2.582549   1.082518  1.0   2.0   2.0    3.0    8.0
# price  9249.0  94.208814  69.857864  8.0  50.0  70.0  113.0  430.0

# %%
mu = xtrain.describe().T['mean']
sigma = xtrain.describe().T['std']

# %%
#normalize both xtrain and xtest with same mu and sigma

xtrain_norm = (xtrain - mu)/sigma
xtest_norm = (xtest - mu)/sigma

# %%
xtrain_norm
# Out:
#                               bath     price
# location
# Uttarahalli              -0.538143 -0.738769
# Karuna Nagar              0.385629  1.084934
# Kodihalli                -0.538143  0.798639
# Raja Rajeshwari Nagar    -0.538143 -0.346544
# Electronics City Phase 1 -0.538143 -0.418118
# ...                            ...       ...
# other                     0.385629 -0.203539
# Dodda Nekkundi           -0.538143 -0.561266
# Harlur                    0.385629  0.426454
# Banashankari Stage VI     1.309401  1.442804
# Bannerghatta             -0.538143 -0.632839
#
# [9249 rows x 2 columns]

# %%
xtest_norm.head()
# Out:
#                             bath     price
# location
# other                   0.385629 -0.346544
# Kengeri Satellite Town -0.538143 -0.232026
# Sarjapur  Road         -0.538143 -0.765681
# other                  -0.538143 -0.530489
# Rajaji Nagar            0.385629  4.592055

# %%
# outliers-> anything greater than 3 or less than -3 z-score is definitely an outlier

xtrain_norm > 3
# Out:
#                            bath  price
# location
# Uttarahalli               False  False
# Karuna Nagar              False  False
# Kodihalli                 False  False
# Raja Rajeshwari Nagar     False  False
# Electronics City Phase 1  False  False
# ...                         ...    ...
# other                     False  False
# Dodda Nekkundi            False  False
# Harlur                    False  False
# Banashankari Stage VI     False  False
# Bannerghatta              False  False
#
# [9249 rows x 2 columns]

# %%
outliers = xtrain_norm[(xtrain_norm > 3) | (xtrain_norm < -3)].dropna(how='all')
outliers
# Out:
#                         bath     price
# location
# Old Madras Road     3.156946       NaN
# 5th Phase JP Nagar  4.080718       NaN
# other               4.080718       NaN
# other               3.156946       NaN
# Kumaraswami Layout  4.080718       NaN
# ...                      ...       ...
# other               3.156946       NaN
# Sarjapur  Road           NaN  3.661595
# BTM 2nd Stage            NaN  4.377334
# Malleshwaram             NaN  3.232151
# other                    NaN  4.091038
#
# [448 rows x 2 columns]

# %%
ytest.value_counts()
# Out:
# price
# 75.00    57
# 60.00    52
# 65.00    51
# 70.00    46
# 45.00    46
#          ..
# 46.60     1
# 79.90     1
# 99.14     1
# 52.20     1
# 36.23     1
# Name: count, Length: 639, dtype: int64

# %%
# algorithms
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
nnmodel = keras.Sequential([Dense(1, activation=tf.nn.sigmoid)])
nnmodel2 = keras.Sequential([
    Dense(10, activation=tf.nn.relu),
    Dense(64, activation=tf.nn.relu),
    Dense(128, activation=tf.nn.relu),
    Dense(1, activation=tf.nn.sigmoid)
])

# %%
nnmodel.compile(loss=keras.losses.binary_crossentropy, optimizer=tf.optimizers.Adam(), metrics=['accuracy'])
nnmodel2.compile(loss=keras.losses.binary_crossentropy, optimizer=tf.optimizers.Adam(), metrics=['accuracy'])

# %%
models = {
    'naive_bayes' : GaussianNB(),
    'knn' : KNeighborsClassifier(),
    'svc' : SVC(),
    'linear_svc' : LinearSVC(),
    'decision_tree' : DecisionTreeClassifier(),
    'decision_tree100' : DecisionTreeClassifier(max_depth=100),
    'decision_tree200' : DecisionTreeClassifier(max_depth=200),
    'decision_tree300' : DecisionTreeClassifier(max_depth=300),
    'random_forest' : RandomForestClassifier(),
    'random_forest200' : RandomForestClassifier(n_estimators=200),
    'random_forest400' : RandomForestClassifier(n_estimators=400),
    'random_forest500' : RandomForestClassifier(n_estimators=500),
    'logistic_regression' : LogisticRegression(),
    'neural_network_linear': nnmodel,
    'neural_network_nonlinear': nnmodel2
}

# %%
#measure the performance of mdoels -> accuracy
# total correct guesses / total guesses
from sklearn.metrics import accuracy_score

# %%
max_accuracy = 0
best_model_name = None
best_model = None
log_model = None
for model_name, model in models.items():
  if(model_name == 'logistic_regression'):
    log_model = model
  if(model_name == 'neural_network_linear' or model_name=='neural_network_nonlinear'):
    history = model.fit(xtrain_norm, ytrain, epochs=100)
    p = model.predict(xtest_norm)
    ytest=ytest.astype('int')
    p=p.astype('int')
  else:
    ytrain=ytrain.astype('int')
    model.fit(xtrain_norm, ytrain)
    p = model.predict(xtest_norm)
    ytest=ytest.astype('int')
    p=p.astype('int')
  print(model_name, accuracy_score(ytest, p))
  print('****')
  if accuracy_score(ytest, p) > max_accuracy:
    max_accuracy = accuracy_score(ytest, p)
    best_model_name = model_name
    best_model = model
# Out:
# naive_bayes 0.9230436662343278
# ****
# knn 0.8953739731949849
# ****
# svc 0.19714656290531776
# ****
# linear_svc 0.08473843493298747
# ****
# decision_tree 0.9865974924340684
# ****
# decision_tree100 0.9874621703415478
# ****
# decision_tree200 0.9870298313878081
# ****
# decision_tree300 0.9865974924340684
# ****
# random_forest 0.9541720709035885
# ****
# random_forest200 0.9541720709035885
# ****
# random_forest400 0.9541720709035885
# ****
# random_forest500 0.9541720709035885
# ****
# logistic_regression 0.10246433203631647
# ****
# Epoch 1/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -10641.4756
# Epoch 2/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11028.2334
# Epoch 3/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -11108.7363
# Epoch 4/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -10892.4570
# Epoch 5/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -10931.0840
# Epoch 6/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11192.8457
# Epoch 7/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -11120.0205
# Epoch 8/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -10689.5811
# Epoch 9/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11286.3740
# Epoch 10/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -10769.2705
# Epoch 11/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -10953.3535
# Epoch 12/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -11591.4727
# Epoch 13/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -11252.2441
# Epoch 14/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11305.3955
# Epoch 15/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11286.8643
# Epoch 16/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11691.0439
# Epoch 17/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -12094.5371
# Epoch 18/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -11410.4004
# Epoch 19/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -11496.8965
# Epoch 20/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -11295.0811
# Epoch 21/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -11932.4443
# Epoch 22/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -12035.7178
# Epoch 23/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12199.2500
# Epoch 24/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12083.8760
# Epoch 25/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12358.1699
# Epoch 26/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -11834.0713
# Epoch 27/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12080.5156
# Epoch 28/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12288.5410
# Epoch 29/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11992.0664
# Epoch 30/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12135.3926
# Epoch 31/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12183.5781
# Epoch 32/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12195.5967
# Epoch 33/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12254.2930
# Epoch 34/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12357.7686
# Epoch 35/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -13023.3721
# Epoch 36/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -11894.8535
# Epoch 37/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12162.6846
# Epoch 38/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12414.1387
# Epoch 39/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12679.8330
# Epoch 40/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -12651.1562
# Epoch 41/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12629.7305
# Epoch 42/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -12881.8662
# Epoch 43/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -13103.3125
# Epoch 44/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -12800.0439
# Epoch 45/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -12638.8184
# Epoch 46/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13129.5010
# Epoch 47/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13294.1465
# Epoch 48/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13508.9023
# Epoch 49/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13104.0586
# Epoch 50/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -13456.5410
# Epoch 51/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13276.9746
# Epoch 52/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -12846.7646
# Epoch 53/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13350.8848
# Epoch 54/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -13242.5166
# Epoch 55/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13387.0439
# Epoch 56/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -13582.2197
# Epoch 57/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13454.7959
# Epoch 58/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -13814.9268
# Epoch 59/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13522.8906
# Epoch 60/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13580.5986
# Epoch 61/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -14012.8203
# Epoch 62/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -13995.5449
# Epoch 63/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -13784.6191
# Epoch 64/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -14523.9453
# Epoch 65/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -13717.9229
# Epoch 66/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -13993.5371
# Epoch 67/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14031.9326
# Epoch 68/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -14334.1338
# Epoch 69/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14300.1973
# Epoch 70/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13764.3574
# Epoch 71/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -14989.2969
# Epoch 72/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -13816.7822
# Epoch 73/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -14048.5068
# Epoch 74/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -14665.0713
# Epoch 75/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14024.4609
# Epoch 76/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -13942.8740
# Epoch 77/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14582.9326
# Epoch 78/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -14269.4326
# Epoch 79/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14682.5273
# Epoch 80/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14670.7324
# Epoch 81/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -14987.5283
# Epoch 82/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14528.8828
# Epoch 83/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -15942.6328
# Epoch 84/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -15475.4629
# Epoch 85/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14915.2754
# Epoch 86/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -15219.3740
# Epoch 87/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -14892.0605
# Epoch 88/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -15519.9746
# Epoch 89/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -15516.1504
# Epoch 90/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -15426.4639
# Epoch 91/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -15809.7607
# Epoch 92/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -14988.8701
# Epoch 93/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -15722.8682
# Epoch 94/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -15598.0723
# Epoch 95/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -15032.3955
# Epoch 96/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -16192.7363
# Epoch 97/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: -16147.4951
# Epoch 98/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -16090.9219
# Epoch 99/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -15914.2676
# Epoch 100/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: -15858.6963
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# neural_network_linear 0.0
# ****
# Epoch 1/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.0000e+00 - loss: -22699.6191
# Epoch 2/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2059450.0000
# Epoch 3/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -21021316.0000
# Epoch 4/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -88641600.0000
# Epoch 5/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -241315680.0000
# Epoch 6/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -507530432.0000
# Epoch 7/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -985890688.0000
# Epoch 8/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1680432512.0000
# Epoch 9/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2647262208.0000
# Epoch 10/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -3750661120.0000
# Epoch 11/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -5565185536.0000
# Epoch 12/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -7459322880.0000
# Epoch 13/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -9833010176.0000
# Epoch 14/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -13051904000.0000
# Epoch 15/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -16324242432.0000
# Epoch 16/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -20358852608.0000
# Epoch 17/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -24454047744.0000
# Epoch 18/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -29849835520.0000
# Epoch 19/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -35837960192.0000
# Epoch 20/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -42874183680.0000
# Epoch 21/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -50136735744.0000
# Epoch 22/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -60034760704.0000
# Epoch 23/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -66159906816.0000
# Epoch 24/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -77886021632.0000
# Epoch 25/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -88697102336.0000
# Epoch 26/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -102615121920.0000
# Epoch 27/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -114749464576.0000
# Epoch 28/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -125565059072.0000
# Epoch 29/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -143534342144.0000
# Epoch 30/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -160888471552.0000
# Epoch 31/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -180946403328.0000
# Epoch 32/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -196666015744.0000
# Epoch 33/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -216765005824.0000
# Epoch 34/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -236418039808.0000
# Epoch 35/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -261646712832.0000
# Epoch 36/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -289270759424.0000
# Epoch 37/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -317533487104.0000
# Epoch 38/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -344193105920.0000
# Epoch 39/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -373377138688.0000
# Epoch 40/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -404205404160.0000
# Epoch 41/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -435063750656.0000
# Epoch 42/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -475800993792.0000
# Epoch 43/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -500783120384.0000
# Epoch 44/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -547186278400.0000
# Epoch 45/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -584111489024.0000
# Epoch 46/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -614030639104.0000
# Epoch 47/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -657669226496.0000
# Epoch 48/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -711998439424.0000
# Epoch 49/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -764968697856.0000
# Epoch 50/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -819364429824.0000
# Epoch 51/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -868874256384.0000
# Epoch 52/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -919651155968.0000
# Epoch 53/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1022461018112.0000
# Epoch 54/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1088807960576.0000
# Epoch 55/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1111867392000.0000
# Epoch 56/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1220334059520.0000
# Epoch 57/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1271985078272.0000
# Epoch 58/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1341474996224.0000
# Epoch 59/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1432827592704.0000
# Epoch 60/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -1523255607296.0000
# Epoch 61/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -1549234208768.0000
# Epoch 62/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -1666435645440.0000
# Epoch 63/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -1770606297088.0000
# Epoch 64/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1883249049600.0000
# Epoch 65/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -1899951947776.0000
# Epoch 66/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2058223091712.0000
# Epoch 67/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2178190409728.0000
# Epoch 68/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2255155101696.0000
# Epoch 69/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2368926121984.0000
# Epoch 70/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2558697144320.0000
# Epoch 71/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2662306152448.0000
# Epoch 72/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2675546521600.0000
# Epoch 73/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -2889027682304.0000
# Epoch 74/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -3039514853376.0000
# Epoch 75/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -3101572464640.0000
# Epoch 76/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -3270602391552.0000
# Epoch 77/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -3431002013696.0000
# Epoch 78/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -3641047777280.0000
# Epoch 79/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0000e+00 - loss: -3720447262720.0000
# Epoch 80/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -3981003718656.0000
# Epoch 81/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -4083698892800.0000
# Epoch 82/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -4252596436992.0000
# Epoch 83/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -4435082215424.0000
# Epoch 84/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -4575861932032.0000
# Epoch 85/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -4844203540480.0000
# Epoch 86/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -4952266637312.0000
# Epoch 87/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -5183947931648.0000
# Epoch 88/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -5472206716928.0000
# Epoch 89/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -5532001239040.0000
# Epoch 90/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -5774293073920.0000
# Epoch 91/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -6045794566144.0000
# Epoch 92/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -6311887503360.0000
# Epoch 93/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -6614455681024.0000
# Epoch 94/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -6788667670528.0000
# Epoch 95/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -6843177369600.0000
# Epoch 96/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -7086632599552.0000
# Epoch 97/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -7500069863424.0000
# Epoch 98/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0000e+00 - loss: -7608599576576.0000
# Epoch 99/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -8072170307584.0000
# Epoch 100/100
# 290/290 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: -8440343691264.0000
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# neural_network_nonlinear 0.0
# ****

# %%
best_model_name
# Out:
# 'decision_tree100'

# %%
best_model
# Out:
# DecisionTreeClassifier(max_depth=100)

# %%
dir(log_model)
# Out:
# ['C',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_predict_proba_lr',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_validate_data',
#  '_validate_params',
#  'class_weight',
#  'classes_',
#  'coef_',
#  'decision_function',
#  'densify',
#  'dual',
#  'feature_names_in_',
#  'fit',
#  'fit_intercept',
#  'get_metadata_routing',
#  'get_params',
#  'intercept_',
#  'intercept_scaling',
#  'l1_ratio',
#  'max_iter',
#  'multi_class',
#  'n_features_in_',
#  'n_iter_',
#  'n_jobs',
#  'penalty',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'random_state',
#  'score',
#  'set_fit_request',
#  'set_params',
#  'set_score_request',
#  'solver',
#  'sparsify',
#  'tol',
#  'verbose',
#  'warm_start']

# %%
log_model.intercept_
# Out:
# array([-0.74639708])

# %%
log_model.coef_
# Out:
# array([[ 1.05936839,  1.41811902,  0.97021857,  1.32475941,  0.96292581,
#         -0.36951312,  0.91820984,  1.45680321,  0.55674293, -0.35310309]])

# %%
len(xtrain_norm.columns)
# Out:
# 10
